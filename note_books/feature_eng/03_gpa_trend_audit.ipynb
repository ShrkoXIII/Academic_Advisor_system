# %% [markdown]
# # GPA trend feature audit
#
# **Purpose:** Run the reusable pre-split GPA-trend audit and inspect its coverage, distribution, reconstruction-gap attribution, and five oracle spot checks.
#
# **Input:** `SELECTED_MODEL_POPULATION_PATH` from `src.paths`
#
# **Output:** a timestamped report under `GPA_TREND_REPORTS_DIR` from `src.paths`. This notebook does not write model-data splits or train a model. All calculations live in `scripts/audit_gpa_trend.py` so the audit is also reproducible from the command line.

# %%
from pathlib import Path
import sys

project_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / 'src').is_dir() and (path / 'scripts').is_dir()
)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import pandas as pd

from scripts.audit_gpa_trend import run_audit
from src.paths import SELECTED_MODEL_POPULATION_PATH

# %%
report, output_dir = run_audit(SELECTED_MODEL_POPULATION_PATH)
print(f'Audit report written to: {output_dir}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 report, output_dir = run_audit(SELECTED_MODEL_POPULATION_PATH)
#       2 print(f'Audit report written to: {output_dir}')
#
# File d:\AI\Real projects\Academic_Advisor\scripts\audit_gpa_trend.py:742, in run_audit(input_path, output_dir, split_dir)
#     738 output_dir = Path(output_dir)
#     739 full_semester, primary_semester, _, source_rows = build_semester_trend_from_source(
#     740     input_path
#     741 )
# --> 742 report = create_semester_audit_report(
#     743     full_semester,
#     744     primary_semester,
#     745     output_dir,
#     746     source_path=input_path,
#     747     source_course_rows=source_rows,
#     748     split_dir=split_dir,
#     749 )
#     750 return report, output_dir
#
# File d:\AI\Real projects\Academic_Advisor\scripts\audit_gpa_trend.py:617, in create_semester_audit_report(full_semester, primary_semester, output_dir, source_path, source_course_rows, split_dir, split_paths)
#     613 output_dir.mkdir(parents=True, exist_ok=False)
#     614 wrong_shift_keys, wrong_shift_diagnostics = _rejected_shift2_diagnostics(
#     615     full_semester
#     616 )
# --> 617 course_coverage, train_delta = _course_coverage_from_split_files(
#     618     primary_semester,
#     619     split_dir,
#     620     wrong_shift_keys=wrong_shift_keys,
#     621     split_paths=split_paths,
#     622 )
#     623 semester_coverage = _coverage_table(primary_semester, semester_grain=True)
#     624 reconstructed_t1 = _strictly_prior_last_valid(full_semester)
#
# File d:\AI\Real projects\Academic_Advisor\scripts\audit_gpa_trend.py:564, in _course_coverage_from_split_files(primary_semester, split_dir, wrong_shift_keys, split_paths)
#     562 for name in SPLITS:
#     563     path = resolved[name]
# --> 564     keys = pd.read_parquet(path, columns=SEMESTER_KEY)
#     565     features = map_trend_to_course_keys(keys, primary_semester)
#     566     has_t2 = features["gpa_trend_delta"].notna()
#
# File d:\AI\Real projects\Academic_Advisor\.venv\Lib\site-packages\pandas\io\parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# File d:\AI\Real projects\Academic_Advisor\.venv\Lib\site-packages\pandas\io\parquet.py:253, in PyArrowImpl.read(self, path, columns, filters, dtype_backend, storage_options, filesystem, to_pandas_kwargs, **kwargs)
#     240 def read(
#     241     self,
#     242     path,
#    (...)    249     **kwargs,
#     250 ) -> DataFrame:
#     251     kwargs["use_pandas_metadata"] = True
# --> 253     path_or_handle, handles, filesystem = _get_path_or_handle(
#     254         path,
#     255         filesystem,
#     256         storage_options=storage_options,
#     257         mode="rb",
#     258     )
#     259     try:
#     260         pa_table = self.api.parquet.read_table(
#     261             path_or_handle,
#     262             columns=columns,
#    (...)    265             **kwargs,
#     266         )
#
# File d:\AI\Real projects\Academic_Advisor\.venv\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File d:\AI\Real projects\Academic_Advisor\.venv\Lib\site-packages\pandas\io\common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\AI\\Real projects\\Academic_Advisor\\data\\model_data\\df_train_final.parquet'

# %% [markdown]
# ## Coverage at both required grains

# %%
pd.DataFrame(report['course_coverage'])

# %%
pd.DataFrame(report['semester_coverage'])

# %% [markdown]
# ## Train distribution and primary-only reconstruction gap

# %%
pd.Series(report['train_delta_distribution'], name='value').to_frame()

# %%
pd.Series(report['reconstruction_gap'], name='value').to_frame()

# %% [markdown]
# ## Five valid-history oracle spot checks
#
# The audit selects at least one interruption timeline and one retake timeline when present. `oracle_t2` is obtained by walking only valid strictly-earlier GPA observations.

# %%
pd.DataFrame(report['spot_checks'])
