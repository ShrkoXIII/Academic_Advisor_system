# %%
import pandas as pd 
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_crg_student_passed_credit.parquet")
df[df['passed_credit'] > df['credits_count']]
# Out:
#        student_id               requirement_type_pl  \
# 1        2722.111     Mandatory Degree Requirements
# 2        2738.111     Mandatory Degree Requirements
# 24       2972.111     Mandatory Degree Requirements
# 32       1567.111     Mandatory Degree Requirements
# 33       1574.111     Mandatory Degree Requirements
# ...           ...                               ...
# 53539     207.111     Optional Faculty Requirements
# 53611   25318.111  Optional University Requirements
# 53770   15622.111  Optional University Requirements
# 53785   22859.111  Optional University Requirements
# 53792   16124.111  Optional University Requirements
#
#               requirement_type_sl  credits_count  passed_credit
# 1       متطلبات الشهادة الإجبارية          193.0          196.0
# 2       متطلبات الشهادة الإجبارية          193.0          196.0
# 24      متطلبات الشهادة الإجبارية          193.0          194.0
# 32      متطلبات الشهادة الإجبارية          193.0          196.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53877 entries, 0 to 53876
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           53877 non-null  float64
#  1   requirement_type_pl  53877 non-null  str
#  2   requirement_type_sl  53877 non-null  str
#  3   credits_count        53877 non-null  float64
#  4   passed_credit        53877 non-null  float64
# dtypes: float64(3), str(2)
# memory usage: 6.1 MB
