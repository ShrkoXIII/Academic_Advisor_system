# %%
import pandas as pd
pd.set_option("display.max_columns", 100)

# %%
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\model_data\df_train_base.parquet")

# %%
df.head()
# Out:
#   student_course_id student_id course_id part_id degree_id faculty_id  \
# 0        939272.111  10000.111  1016.111   20152     3.111      5.111
# 1        953865.111  10000.111  1017.111   20153     3.111      5.111
# 2       1076397.111  10000.111  1019.111   20171     3.111      5.111
# 3        925010.111  10000.111   431.111   20152     3.111      5.111
# 4        901340.111  10000.111   432.111   20151     3.111      5.111
#
#   grade_id  final_mark  course_credits  attempt_number student_status_id  \
# 0  677.111          82             2.0               1        155348.111
# 1  680.111          67             2.0               1        155349.111
# 2  981.111          66             2.0               1        240678.111
# 3  677.111          83             3.0               1        155348.111
# 4  681.111          61             4.0               1        155347.111
#
#    prev_gpa_points  gpa_points  start_agpa_points  start_total_in_courses  \
# ...

# %%
df.columns
# Out:
# Index(['student_course_id', 'student_id', 'course_id', 'part_id', 'degree_id',
#        'faculty_id', 'grade_id', 'final_mark', 'course_credits',
#        'attempt_number', 'student_status_id', 'prev_gpa_points', 'gpa_points',
#        'start_agpa_points', 'start_total_in_courses', 'start_total_in_credits',
#        'semester_reg_credits', 'semester_reg_courses', 'semester_pass_credits',
#        'total_pass_credits', 'total_fail_credits', 'reg_total_semesters',
#        'start_level_name_pl', 'start_part_id', 'requirement_type_id',
#        'degree_requirement_credits_count', 'diploma_gpa', 'diploma_type_id',
#        'university_id', 'is_high_credit_course',
#        'over_policy_semester_credits', 'over_policy_semester_courses',
#        'exclude_over_policy_semester', 'is_extreme_fail_history',
#        'total_fail_credits_capped', 'is_interruption_semester',
#        'prev_semester_was_interruption', 'prior_interruption_count',
# ...

# %%
df.shape
# Out:
# (606563, 65)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 606563 entries, 0 to 749522
# Data columns (total 65 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   student_course_id                         606563 non-null  string
#  1   student_id                                606563 non-null  string
#  2   course_id                                 606563 non-null  str
#  3   part_id                                   606563 non-null  string
#  4   degree_id                                 606563 non-null  string
#  5   faculty_id                                606563 non-null  string
#  6   grade_id                                  606563 non-null  string
#  7   final_mark                                606563 non-null  Int64
#  8   course_credits                            606563 non-null  Float64
#  9   attempt_number                            606563 non-null  Int64
# ...

# %%
nulls = df.isnull().sum()
nulls[nulls > 0].sort_values(ascending=False)
# Out:
# gpa_trend_delta                           151119
# last_valid_gpa_before_current_semester     82357
# model_prev_gpa                             78490
# prev_gpa_points                            75312
# reg_total_semesters                         2681
# diploma_type_id                               31
# dtype: int64
