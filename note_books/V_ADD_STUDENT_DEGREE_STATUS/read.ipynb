# %%
import pandas as pd

from src.paths import RAW_DIR

pd.set_option('display.max_columns', 50)
raw_path = RAW_DIR / "v_add_student_degree_status.parquet"

# %%
df_row = pd.read_parquet(raw_path)

# %%
df_row.head()

# %%
df_row.info()

# %%
df_row.isna().sum()

# %%
df_row=df_row[df_row['gpa_percent'].notnull()]

# %%
df_row.isna().sum()

# %%
df_row['finish_status'].value_counts()

# %%
df_row[df_row['finish_status'].eq("GRADUATED")]
