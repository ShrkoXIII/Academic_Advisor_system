# %%
import pandas as pd 
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_add_student_degree_status_clean.parquet")
pd.set_option("display.max_columns", None)

# %%
df.describe()
# Out:
#             part_id    part_year  part_semester_no  gpa_percent  gpa_points  \
# count      154768.0     154768.0          154768.0     154768.0    154768.0
# mean   20192.223263  2019.033528          1.887987    56.519266    1.808421
# std       35.020266     3.510157          0.858061    26.146758    1.052316
# min         20051.0       2005.0               1.0          0.0         0.0
# 25%         20164.0       2016.0               1.0         50.0        1.08
# 50%         20201.0       2020.0               2.0        63.94        2.05
# 75%         20221.0       2022.0               3.0         74.0        2.61
# max         20254.0       2025.0               4.0        100.0         4.0
#
#        start_part_id  start_part_year  start_part_semester_no  finish_part_id  \
# count       154763.0         154763.0                154763.0        107879.0
# mean    20167.982677       2016.68654                1.117276    20207.811326
# ...

# %%
add=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_add_student_degree_status.parquet")

# %%
add.head()
# Out:
#    student_status_id  student_id  request_id  part_id  degree_id study_mode  \
# 0         340275.111   28401.111  570675.111  20222.0      1.111          C
# 1         334725.111   28401.111  550329.111  20221.0      1.111          C
# 2         353697.111   28401.111  618048.111  20231.0      1.111          C
# 3         361412.111   28401.111  648593.111  20232.0      1.111          C
# 4         374249.111   28401.111  702262.111  20241.0      1.111          C
#
#    gpa_percent  gpa_points  start_part_id  finish_part_id  start_agpa_percent  \
# 0        84.25        3.16        20221.0             NaN               89.07
# 1        89.07        3.34        20221.0             NaN                0.00
# 2        85.28        3.15        20221.0             NaN               86.24
# 3        85.45        3.18        20221.0             NaN               85.90
# 4        88.41        3.31        20221.0             NaN               85.78
#
# ...

# %%
d=add.describe()
d.to_csv(r"D:\AI\Real projects\Academic_Advisor\decribe.csv")

# %%
d
# Out:
#        student_status_id     student_id     request_id        part_id  \
# count      154779.000000  154779.000000  146661.000000  154779.000000
# mean       278818.125847   12619.951120  343303.190604   20192.225308
# std         70557.472276    6133.201133  224592.506891      35.019862
# min        113278.111000      48.111000    7157.111000   20051.000000
# 25%        236841.611000    9365.111000  146497.111000   20164.000000
# 50%        286820.111000   11940.111000  271619.111000   20201.000000
# 75%        330925.611000   14938.111000  538037.111000   20221.000000
# max        403812.111000   28890.111000  844441.000000   20254.000000
#
#            degree_id    gpa_percent     gpa_points  start_part_id  \
# count  152653.000000  154768.000000  154768.000000  154774.000000
# mean        7.731702      56.519266       1.808421   20167.986445
# std         7.166146      26.146758       1.052316      33.068373
# min         1.111000       0.000000       0.000000   20051.000000
# ...

# %%
df1[df1['semester_pass_credits'].eq(49.000000)]
# Out:
#        student_status_id  student_id  request_id  part_id  degree_id  \
# 91521         342705.111   11015.111  577073.111  20222.0      2.111
#
#       study_mode  gpa_percent  gpa_points  start_part_id  finish_part_id  \
# 91521          C         62.0         2.1        20161.0         20222.0
#
#        start_agpa_percent  start_agpa_points  end_agpa_percent  \
# 91521                64.4               2.22              65.6
#
#        end_agpa_points  semester_reg_courses  semester_reg_credits  \
# 91521             2.28                   7.0                  49.0
#
#        semester_pass_courses  semester_pass_credits  semester_fail_courses  \
# 91521                    7.0                   49.0                    0.0
#
#        semester_fail_credits  total_pass_courses  total_pass_credits  \
# 91521                    0.0                63.0               228.0
#
#        total_fail_courses  total_fail_credits  reg_total_semesters  \
# ...

# %%
df1[df1['semester_reg_credits'].eq(72.500000)]
# Out:
#        student_status_id  student_id  request_id  part_id  degree_id  \
# 88105         236604.111    3472.111  141352.111  20164.0      2.111
#
#       study_mode  gpa_percent  gpa_points  start_part_id  finish_part_id  \
# 88105          C        34.37        0.12        20131.0             NaN
#
#        start_agpa_percent  start_agpa_points  end_agpa_percent  \
# 88105                48.5               0.95             49.92
#
#        end_agpa_points  semester_reg_courses  semester_reg_credits  \
# 88105             1.01                  16.0                  72.5
#
#        semester_pass_courses  semester_pass_credits  semester_fail_courses  \
# 88105                    1.0                    6.0                   15.0
#
#        semester_fail_credits  total_pass_courses  total_pass_credits  \
# 88105                   66.5                46.0               152.5
#
#        total_fail_courses  total_fail_credits  reg_total_semesters  \
# ...

# %%
df2=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_crg_student_course_raw.parquet")
test=df2[(df2['student_id'].eq(3472.111))&(df2['part_id'].eq(20164.0))]

# %%
test.to_csv(r"D:\AI\Real projects\Academic_Advisor\test.csv")

# %%
test1=df2[(df2['student_id'].eq(11015.111))&(df2['part_id'].eq(20222.0))]

# %%
test1.to_csv(r"D:\AI\Real projects\Academic_Advisor\test1.csv")

# %%
df1[df1['total_fail_credits'].eq(713.500000)]
# Out:
#        student_status_id  student_id  request_id  part_id  degree_id  \
# 88078         301185.111    3470.111  334312.111  20203.0      2.111
# 88079         321187.111    3470.111  517663.111  20213.0      2.111
# 88080         358127.111    3470.111         NaN  20231.0      2.111
# 88083         308846.111    3470.111  347651.111  20211.0      2.111
# 88084         315139.111    3470.111  455891.111  20212.0      2.111
# 88085         330847.111    3470.111  537520.111  20221.0      2.111
# 88086         371794.111    3470.111         NaN  20232.0      2.111
#
#       study_mode  gpa_percent  gpa_points  start_part_id  finish_part_id  \
# 88078          C        59.50        1.88        20161.0         20232.0
# 88079          C        99.00        4.00        20161.0         20232.0
# 88080          C         0.00        0.00        20161.0         20232.0
# 88083          C        66.67        2.25        20161.0         20232.0
# ...

# %%
test2=df2[(df2['student_id'].eq(3470.111))&(df2['finish_status'].eq('F'))]
test2
# Out:
#         student_course_id  student_id  course_id  part_id  grade_id  \
# 132382         988015.111    3470.111    699.111  20161.0   985.111
# 132383         988016.111    3470.111    698.111  20161.0   985.111
# 137076         988115.111    3470.111    711.111  20161.0   985.111
# 154623        1048134.111    3470.111    711.111  20164.0   985.111
# 154624        1048135.111    3470.111    698.111  20164.0   985.111
# 154625        1048136.111    3470.111    699.111  20164.0   985.111
# 154626        1048138.111    3470.111    665.111  20164.0   985.111
# 188099        1039920.111    3470.111    665.111  20163.0   985.111
# 232269        1082977.111    3470.111    704.111  20171.0   985.111
# 241454        1082883.111    3470.111    709.111  20171.0   985.111
# 241455        1082884.111    3470.111    696.111  20171.0   985.111
# 252554        1120635.111    3470.111    697.111  20172.0   985.111
# 255777        1116501.111    3470.111    706.111  20172.0   985.111
# ...

# %%
test2['active'].value_counts()
# Out:
# active
# A    33
# Name: count, dtype: int64

# %%
test2.to_csv(r"D:\AI\Real projects\Academic_Advisor\test2.csv")

# %%
df[df['semester_fail_credits'].eq(66.500000)]
# Out:
#       student_status_id student_id  part_id  part_year  part_semester_no  \
# 88104        236604.111   3472.111    20164       2016                 4
#
#       degree_id study_mode  gpa_percent  gpa_points  start_part_id  \
# 88104     2.111          C        34.37        0.12          20131
#
#        start_part_year  start_part_semester_no  finish_part_id  \
# 88104             2013                       1            <NA>
#
#        finish_part_year  finish_part_semester_no  start_agpa_percent  \
# 88104              <NA>                     <NA>                48.5
#
#        start_agpa_points  end_agpa_percent  end_agpa_points  \
# 88104               0.95             49.92             1.01
#
#        semester_reg_courses  semester_reg_credits  semester_pass_courses  \
# 88104                    16                  72.5                      1
#
#        semester_pass_credits  semester_fail_courses  semester_fail_credits  \
# ...

# %%
test3=df2[(df2['student_id'].eq(3472.111))&(df2['part_id'].eq(20164))]

# %%
test3.to_csv(r"D:\AI\Real projects\Academic_Advisor\test3.csv")

# %%
test3[test3['course_id'].eq(676.111)]
# Out:
#         student_course_id  student_id  course_id  part_id  grade_id  \
# 168769        1049771.111    3472.111    676.111  20164.0   985.111
# 176159        1048688.111    3472.111    676.111  20164.0       NaN
#
#         final_mark  points finish_status               course_name_sl  \
# 168769        31.0     0.0             F  الكيمياء الحيوية الطبية (1)
# 176159         NaN     NaN           NaN  الكيمياء الحيوية الطبية (1)
#
#        register_status study_mode  degree_id degree_name_sl  faculty_id  \
# 168769               E          C      2.111  دكتور في الطب       2.111
# 176159               D          C      2.111  دكتور في الطب       2.111
#
#         course_credits active
# 168769             5.0      A
# 176159             5.0      A

# %%
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\audit\V_ADD_STUDENT_DEGREE_STATUS\isolated_status_rows_v1.parquet")

# %%
a=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_crg_student_course_raw.parquet")

# %%
b=a['student_id'].unique()
len(b)
# Out:
# 16686

# %%
add_student=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_add_student_degree_status.parquet")
b=add_student['student_id'].unique()
len(b)
# Out:
# 14516

# %%
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_add_student_degree_status_clean.parquet")
