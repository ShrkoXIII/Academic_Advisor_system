# %% [markdown]
# <!-- codex-architecture-notes -->
# ## Architectural Notes
#
# **Purpose:** Loads the main cleaned preprocessing tables together for broad inspection or manual join checks.
#
# **Notebook Shape:** 14 cells (14 code, 0 markdown).
#
# **Inputs / Data Sources:**
# - `df_crg=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_CRG_STUDENT_COURSE\clean_v_crg_student_course.parquet")`
# - `df_add=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ADD_STUDENT_DEGREE_STATUS\clean_v_add_student_degree_status.parquet")`
# - `df_acd=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ACD_DEGREE_COURSE\v_acd_degree_course.parquet")`
# - `df_acs=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ACS_GRADE\clean_v_acs_grade.parquet")`
#
# **Outputs / Side Effects:**
# - `No explicit persisted output detected; side effects are limited to notebook display state unless cells are edited.`
#
# **Logic Flow:**
# 1. Read cleaned CRG, ADD, ACD, and ACS parquet tables.
# 2. Inspect shapes and shared keys.
# 3. Experiment with cross-table comparisons.
#
# **Maintainability Notes:** This is an aggregation scratchpad; avoid leaving canonical merge rules only in this notebook.

# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)
pd.set_option("display.max_colwidth", 120)

# %%
from src.paths import PREPROCESSED_DIR

df_crg = pd.read_parquet(PREPROCESSED_DIR / "V_CRG_STUDENT_COURSE" / "clean_v_crg_student_course.parquet")
df_add = pd.read_parquet(PREPROCESSED_DIR / "V_ADD_STUDENT_DEGREE_STATUS" / "clean_v_add_student_degree_status.parquet")
df_acd = pd.read_parquet(PREPROCESSED_DIR / "V_ACD_DEGREE_COURSE" / "v_acd_degree_course.parquet")
df_acs = pd.read_parquet(PREPROCESSED_DIR / "V_ACS_GRADE" / "clean_v_acs_grade.parquet")

# %%
df_acd.shape

# %%
df_acd.info()

# %%
df_acd.head(2)

# %%
df_acs.shape

# %%
df_acs.head(2)

# %%
df_crg.shape

# %%
df_crg.head(2)

# %%
df_add.shape

# %%
df_add.head(2)
