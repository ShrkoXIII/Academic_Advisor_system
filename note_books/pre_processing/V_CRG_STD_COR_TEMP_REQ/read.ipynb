# %% [markdown]
# <!-- codex-architecture-notes -->
# ## Architectural Notes
#
# **Purpose:** Inspects the raw temporary course-request table.
#
# **Notebook Shape:** 2 cells (2 code, 0 markdown).
#
# **Inputs / Data Sources:**
# - `df=pd.read_parquet(r'D:\AI\Real projects\Academic_Advisor\data\raw\v_crg_std_cor_temp_request.parquet')`
#
# **Outputs / Side Effects:**
# - `No explicit persisted output detected; side effects are limited to notebook display state unless cells are edited.`
#
# **Logic Flow:**
# 1. Load raw temporary request parquet.
# 2. Inspect shape, columns, and sample records.
#
# **Maintainability Notes:** Currently exploratory; decide whether this table is part of candidate-course generation before adding production dependencies.

# %%
import pandas as pd 
pd.set_option('display.max_columns', 200)

# %%
df=pd.read_parquet(r'D:\AI\Real projects\Academic_Advisor\data\raw\v_crg_std_cor_temp_request.parquet')
df.tail(50)
