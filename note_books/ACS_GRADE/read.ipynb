# %%
import pandas as pd 
# pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 100)

# %%
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_acs_grade.parquet")
df.head(8)
# Out:
#    grade_id  grade_version_id       version_title_sl version_number  \
# 0       NaN             1.000                    NaN            NaN
# 1   673.111             2.111  القرار الوزاري الموحد              2
# 2   999.111             1.111          تأسيس الجامعة              1
# 3   974.111             3.111         القرار رقم 230            230
# 4   674.111             2.111  القرار الوزاري الموحد              2
# 5    85.111             1.111          تأسيس الجامعة              1
# 6       NaN             1.000                    NaN            NaN
# 7   975.111             3.111         القرار رقم 230            230
#
#    from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 0           NaN         NaN     NaN               NaN               NaN
# 1          98.0       100.0    4.00           20111.0           20162.0
# 2           0.0         0.0    0.00           20051.0           20111.0
# 3          98.0       100.0    4.00           20162.0               NaN
# 4          95.0        97.0    3.75           20111.0           20162.0
# 5          90.0       100.0    4.00           20051.0           20111.0
# 6           NaN         NaN     NaN               NaN               NaN
# 7          95.0        97.0    3.75           20162.0               NaN
#
#   finish_status grade_show active
# 0           NaN        NaN      A
# 1             P         A+      A
# 2           NaN        NaN      A
# 3             P         A+      A
# 4             P          A      A
# 5             P          A      A
# 6           NaN        NaN      A
# 7             P          A      A

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   grade_id          79 non-null     float64
#  1   grade_version_id  108 non-null    float64
#  2   version_title_sl  82 non-null     str
#  3   version_number    82 non-null     str
#  4   from_percent      77 non-null     float64
#  5   to_percent        77 non-null     float64
#  6   points            77 non-null     float64
#  7   from_semester_id  82 non-null     float64
#  8   till_semester_id  54 non-null     float64
#  9   finish_status     73 non-null     str
#  10  grade_show        70 non-null     str
#  11  active            108 non-null    str
# dtypes: float64(7), str(5)
# memory usage: 13.1 KB

# %%
df['grade_id'].isna().sum()
df[df['grade_id'].isna()]
# Out:
#      grade_id  grade_version_id       version_title_sl version_number  \
# 0         NaN             1.000                    NaN            NaN
# 6         NaN             1.000                    NaN            NaN
# 8         NaN             1.000                    NaN            NaN
# 12        NaN             1.000                    NaN            NaN
# 16        NaN             1.000                    NaN            NaN
# 21        NaN             1.000                    NaN            NaN
# 24        NaN             1.000                    NaN            NaN
# 29        NaN             1.000                    NaN            NaN
# 33        NaN             1.000                    NaN            NaN
# 39        NaN             1.000                    NaN            NaN
# 42        NaN             1.000                    NaN            NaN
# 45        NaN             1.000                    NaN            NaN
# 49        NaN             1.000                    NaN            NaN
# 53        NaN             1.000                    NaN            NaN
# 57        NaN             1.000                    NaN            NaN
# 62        NaN             1.000                    NaN            NaN
# 67        NaN             1.000                    NaN            NaN
# 71        NaN             1.000                    NaN            NaN
# 73        NaN             1.000                    NaN            NaN
# 77        NaN             1.000                    NaN            NaN
# 82        NaN             1.000                    NaN            NaN
# 84        NaN             1.000                    NaN            NaN
# 92        NaN             1.000                    NaN            NaN
# 93        NaN             1.000                    NaN            NaN
# 102       NaN             1.000                    NaN            NaN
# 104       NaN             1.111          تأسيس الجامعة              1
# 105       NaN             2.111  القرار الوزاري الموحد              2
# 106       NaN             3.111         القرار رقم 230            230
# 107       NaN             1.000                    NaN            NaN
#
#      from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 0             NaN         NaN     NaN               NaN               NaN
# 6             NaN         NaN     NaN               NaN               NaN
# 8             NaN         NaN     NaN               NaN               NaN
# 12            NaN         NaN     NaN               NaN               NaN
# 16            NaN         NaN     NaN               NaN               NaN
# 21            NaN         NaN     NaN               NaN               NaN
# 24            NaN         NaN     NaN               NaN               NaN
# 29            NaN         NaN     NaN               NaN               NaN
# 33            NaN         NaN     NaN               NaN               NaN
# 39            NaN         NaN     NaN               NaN               NaN
# 42            NaN         NaN     NaN               NaN               NaN
# 45            NaN         NaN     NaN               NaN               NaN
# 49            NaN         NaN     NaN               NaN               NaN
# 53            NaN         NaN     NaN               NaN               NaN
# 57            NaN         NaN     NaN               NaN               NaN
# 62            NaN         NaN     NaN               NaN               NaN
# 67            NaN         NaN     NaN               NaN               NaN
# 71            NaN         NaN     NaN               NaN               NaN
# 73            NaN         NaN     NaN               NaN               NaN
# 77            NaN         NaN     NaN               NaN               NaN
# 82            NaN         NaN     NaN               NaN               NaN
# 84            NaN         NaN     NaN               NaN               NaN
# 92            NaN         NaN     NaN               NaN               NaN
# 93            NaN         NaN     NaN               NaN               NaN
# 102           NaN         NaN     NaN               NaN               NaN
# 104           NaN         NaN     NaN           20051.0           20111.0
# 105           NaN         NaN     NaN           20111.0           20162.0
# 106           NaN         NaN     NaN           20162.0               NaN
# 107           NaN         NaN     NaN               NaN               NaN
#
#     finish_status grade_show active
# 0             NaN        NaN      A
# 6             NaN        NaN      A
# 8             NaN        NaN      A
# 12            NaN        NaN      A
# 16            NaN        NaN      A
# 21            NaN        NaN      A
# 24            NaN        NaN      A
# 29            NaN        NaN      A
# 33            NaN        NaN      A
# 39            NaN        NaN      A
# 42            NaN        NaN      A
# 45            NaN        NaN      A
# 49            NaN        NaN      A
# 53            NaN        NaN      A
# 57            NaN        NaN      A
# 62            NaN        NaN      A
# 67            NaN        NaN      A
# 71            NaN        NaN      A
# 73            NaN        NaN      A
# 77            NaN        NaN      A
# 82            NaN        NaN      A
# 84            NaN        NaN      A
# 92            NaN        NaN      A
# 93            NaN        NaN      A
# 102           NaN        NaN      A
# 104           NaN        NaN      A
# 105           NaN        NaN      A
# 106           NaN        NaN      A
# 107           NaN        NaN      A

# %%
df1=df.drop(df[df['grade_id'].isna()].index,)

# %%
df1
# Out:
#      grade_id  grade_version_id       version_title_sl version_number  \
# 1     673.111             2.111  القرار الوزاري الموحد              2
# 2     999.111             1.111          تأسيس الجامعة              1
# 3     974.111             3.111         القرار رقم 230            230
# 4     674.111             2.111  القرار الوزاري الموحد              2
# 5      85.111             1.111          تأسيس الجامعة              1
# ..        ...               ...                    ...            ...
# 98   1006.111             2.111  القرار الوزاري الموحد              2
# 99   1006.111             2.111  القرار الوزاري الموحد              2
# 100  1005.111             3.111         القرار رقم 230            230
# 101  1007.111             2.111  القرار الوزاري الموحد              2
# 103  1009.111             1.111          تأسيس الجامعة              1
#
#      from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 1            98.0       100.0    4.00           20111.0           20162.0
# 2             0.0         0.0    0.00           20051.0           20111.0
# 3            98.0       100.0    4.00           20162.0               NaN
# 4            95.0        97.0    3.75           20111.0           20162.0
# 5            90.0       100.0    4.00           20051.0           20111.0
# ..            ...         ...     ...               ...               ...
# 98            0.0         0.0    0.00           20111.0           20162.0
# 99            0.0         0.0    0.00           20111.0           20162.0
# 100           0.0         0.0    0.00           20162.0               NaN
# 101           0.0         0.0    0.00           20111.0           20162.0
# 103           0.0         0.0    0.00           20051.0           20111.0
#
#     finish_status grade_show active
# 1               P         A+      A
# 2             NaN        NaN      A
# 3               P         A+      A
# 4               P          A      A
# 5               P          A      A
# ..            ...        ...    ...
# 98              X          X      A
# 99              X          X      A
# 100             L          L      A
# 101             L          L      A
# 103             L          L      A
#
# [79 rows x 12 columns]

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 79 entries, 1 to 103
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   grade_id          79 non-null     float64
#  1   grade_version_id  79 non-null     float64
#  2   version_title_sl  79 non-null     str
#  3   version_number    79 non-null     str
#  4   from_percent      77 non-null     float64
#  5   to_percent        77 non-null     float64
#  6   points            77 non-null     float64
#  7   from_semester_id  79 non-null     float64
#  8   till_semester_id  52 non-null     float64
#  9   finish_status     73 non-null     str
#  10  grade_show        70 non-null     str
#  11  active            79 non-null     str
# dtypes: float64(7), str(5)
# memory usage: 10.8 KB

# %%
df1["till_semester_id"] = df1["till_semester_id"].fillna(99999)

# %%
df1[df1["version_number"].eq("230")]
# Out:
#      grade_id  grade_version_id version_title_sl version_number  from_percent  \
# 3     974.111             3.111   القرار رقم 230            230          98.0
# 7     975.111             3.111   القرار رقم 230            230          95.0
# 9     976.111             3.111   القرار رقم 230            230          90.0
# 14    977.111             3.111   القرار رقم 230            230          85.0
# 17    978.111             3.111   القرار رقم 230            230          80.0
# 22    979.111             3.111   القرار رقم 230            230          75.0
# 27    980.111             3.111   القرار رقم 230            230          70.0
# 30    981.111             3.111   القرار رقم 230            230          65.0
# 35    982.111             3.111   القرار رقم 230            230          60.0
# 38    983.111             3.111   القرار رقم 230            230          55.0
# 43    984.111             3.111   القرار رقم 230            230          50.0
# 46    985.111             3.111   القرار رقم 230            230           0.0
# 48    986.111             3.111   القرار رقم 230            230           0.0
# 52    987.111             3.111   القرار رقم 230            230           0.0
# 59    988.111             3.111   القرار رقم 230            230           0.0
# 63    989.111             3.111   القرار رقم 230            230           0.0
# 66    990.111             3.111   القرار رقم 230            230           0.0
# 70    993.111             3.111   القرار رقم 230            230           0.0
# 74    991.111             3.111   القرار رقم 230            230           0.0
# 76    992.111             3.111   القرار رقم 230            230           0.0
# 83    994.111             3.111   القرار رقم 230            230           0.0
# 86    995.111             3.111   القرار رقم 230            230           0.0
# 94   1006.101             3.111   القرار رقم 230            230           0.0
# 95   1004.111             3.111   القرار رقم 230            230           0.0
# 96   1006.101             3.111   القرار رقم 230            230           0.0
# 97   1004.111             3.111   القرار رقم 230            230           0.0
# 100  1005.111             3.111   القرار رقم 230            230           0.0
#
#      to_percent  points  from_semester_id  till_semester_id finish_status  \
# 3         100.0    4.00           20162.0           99999.0             P
# 7          97.0    3.75           20162.0           99999.0             P
# 9          94.0    3.50           20162.0           99999.0             P
# 14         89.0    3.25           20162.0           99999.0             P
# 17         84.0    3.00           20162.0           99999.0             P
# 22         79.0    2.75           20162.0           99999.0             P
# 27         74.0    2.50           20162.0           99999.0             P
# 30         69.0    2.25           20162.0           99999.0             P
# 35         64.0    2.00           20162.0           99999.0             P
# 38         59.0    1.75           20162.0           99999.0             P
# 43         54.0    1.50           20162.0           99999.0             P
# 46         49.0    0.00           20162.0           99999.0             F
# 48          0.0    0.00           20162.0           99999.0             W
# 52          0.0    0.00           20162.0           99999.0            FA
# 59          0.0    0.00           20162.0           99999.0             I
# 63          0.0    0.00           20162.0           99999.0             T
# 66          0.0    0.00           20162.0           99999.0            IP
# 70          0.0    0.00           20162.0           99999.0           NaN
# 74          0.0    0.00           20162.0           99999.0             D
# 76          0.0    0.00           20162.0           99999.0             Z
# 83          0.0    0.00           20162.0           99999.0            ST
# 86          0.0    0.00           20162.0           99999.0            FE
# 94          0.0    0.00           20162.0           99999.0             X
# 95          0.0    0.00           20162.0           99999.0             X
# 96          0.0    0.00           20162.0           99999.0             X
# 97          0.0    0.00           20162.0           99999.0             X
# 100         0.0    0.00           20162.0           99999.0             L
#
#       grade_show active
# 3             A+      A
# 7              A      A
# 9             A-      A
# 14            B+      A
# 17             B      A
# 22            B-      A
# 27            C+      A
# 30             C      A
# 35            C-      A
# 38            D+      A
# 43             D      A
# 46             F      A
# 48             W      A
# 52             Z      A
# 59             I      A
# 63             P      A
# 66             I      A
# 70             F      A
# 74             Z      A
# 76             Z      A
# 83   تدريب سريري      A
# 86           NaN      A
# 94           NaN      A
# 95             X      A
# 96           NaN      A
# 97             X      A
# 100            L      A

# %%
df1[df1['from_percent'].isna()]
# Out:
#     grade_id  grade_version_id version_title_sl version_number  from_percent  \
# 89  1008.101             1.111    تأسيس الجامعة              1           NaN
# 91  1008.101             1.111    تأسيس الجامعة              1           NaN
#
#     to_percent  points  from_semester_id  till_semester_id finish_status  \
# 89         NaN     NaN           20051.0           20111.0             X
# 91         NaN     NaN           20051.0           20111.0             X
#
#    grade_show active
# 89          X      A
# 91          X      A

# %%
df1.drop(df1[df1['from_percent'].isna()].index, inplace=True)

# %%
df['till_semester_id'].value_counts()
# Out:
# till_semester_id
# 20111.0    28
# 20162.0    26
# Name: count, dtype: int64

# %%
df['version_number'].value_counts()
# Out:
# version_number
# 1      28
# 230    28
# 2      26
# Name: count, dtype: int64

# %%
df1[df1['finish_status'].isna()]
# Out:
#     grade_id  grade_version_id       version_title_sl version_number  \
# 2    999.111             1.111          تأسيس الجامعة              1
# 37  1000.111             1.111          تأسيس الجامعة              1
# 68   996.111             2.111  القرار الوزاري الموحد              2
# 69  1001.111             1.111          تأسيس الجامعة              1
# 70   993.111             3.111         القرار رقم 230            230
# 78   972.111             1.111          تأسيس الجامعة              1
#
#     from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 2            0.0         0.0     0.0           20051.0           20111.0
# 37           0.0         0.0     0.0           20051.0           20111.0
# 68           0.0         0.0     0.0           20111.0           20162.0
# 69           0.0         0.0     0.0           20051.0           20111.0
# 70           0.0         0.0     0.0           20162.0           99999.0
# 78           0.0         0.0     0.0           20051.0           20111.0
#
#    finish_status grade_show active
# 2            NaN        NaN      A
# 37           NaN        NaN      A
# 68           NaN          F      A
# 69           NaN        NaN      A
# 70           NaN          F      A
# 78           NaN        NaN      A

# %%
df1 = df1.dropna(subset=["finish_status"]).copy()

print("Remaining null finish_status:", df1["finish_status"].isna().sum())
# Out:
# Remaining null finish_status: 0

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 71 entries, 1 to 103
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   grade_id          71 non-null     float64
#  1   grade_version_id  71 non-null     float64
#  2   version_title_sl  71 non-null     str
#  3   version_number    71 non-null     str
#  4   from_percent      71 non-null     float64
#  5   to_percent        71 non-null     float64
#  6   points            71 non-null     float64
#  7   from_semester_id  71 non-null     float64
#  8   till_semester_id  71 non-null     float64
#  9   finish_status     71 non-null     str
#  10  grade_show        66 non-null     str
#  11  active            71 non-null     str
# dtypes: float64(7), str(5)
# memory usage: 9.7 KB

# %%
df1[df1['grade_id'].eq(	1008.101)]
# Out:
# Empty DataFrame
# Columns: [grade_id, grade_version_id, version_title_sl, version_number, from_percent, to_percent, points, from_semester_id, till_semester_id, finish_status, grade_show, active]
# Index: []

# %%
df1[df1['finish_status'].isna()]
# Out:
# Empty DataFrame
# Columns: [grade_id, grade_version_id, version_title_sl, version_number, from_percent, to_percent, points, from_semester_id, till_semester_id, finish_status, grade_show, active]
# Index: []

# %%
df1 = df1[df1["finish_status"].astype("string").str.strip().ne("1008.101")].copy()

# %%
df1 = df1[df1["grade_id"].ne(1006.101)].copy()

# %%
df1[df1['grade_show'].isna()]
df1=df1.reset_index()

# %%
df1[df1['grade_show'].isna()]
# Out:
#     index  grade_id  grade_version_id       version_title_sl version_number  \
# 57     85   998.111             2.111  القرار الوزاري الموحد              2
# 58     86   995.111             3.111         القرار رقم 230            230
# 59     87  1003.111             1.111          تأسيس الجامعة              1
#
#     from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 57           0.0         0.0     0.0           20111.0           20162.0
# 58           0.0         0.0     0.0           20162.0           99999.0
# 59           0.0         0.0     0.0           20051.0           20111.0
#
#    finish_status grade_show active
# 57            FE        NaN      A
# 58            FE        NaN      A
# 59            FE        NaN      A

# %%
df1['grade_show'].fillna("FE")
# Out:
# 0     A+
# 1     A+
# 2      A
# 3      A
# 4      A
#       ..
# 64     X
# 65     X
# 66     L
# 67     L
# 68     L
# Name: grade_show, Length: 69, dtype: str

# %%
df1.reset_index()
df1=df1.drop(columns=['index'])

# %%
df1.columns
# Out:
# Index(['grade_id', 'grade_version_id', 'version_title_sl', 'version_number',
#        'from_percent', 'to_percent', 'points', 'from_semester_id',
#        'till_semester_id', 'finish_status', 'grade_show', 'active'],
#       dtype='str')

# %%
df1.dtypes
# Out:
# grade_id            float64
# grade_version_id    float64
# version_title_sl        str
# version_number          str
# from_percent        float64
# to_percent          float64
# points              float64
# from_semester_id    float64
# till_semester_id    float64
# finish_status           str
# grade_show              str
# active                  str
# dtype: object

# %%
df1.to_csv(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ACS_GRADE\v_acs_grade.csv",index=False)

# %%
df1.head()
# Out:
#    grade_id  grade_version_id       version_title_sl version_number  \
# 0   673.111             2.111  القرار الوزاري الموحد              2
# 1   974.111             3.111         القرار رقم 230            230
# 2   674.111             2.111  القرار الوزاري الموحد              2
# 3    85.111             1.111          تأسيس الجامعة              1
# 4   975.111             3.111         القرار رقم 230            230
#
#    from_percent  to_percent  points  from_semester_id  till_semester_id  \
# 0          98.0       100.0    4.00           20111.0           20162.0
# 1          98.0       100.0    4.00           20162.0           99999.0
# 2          95.0        97.0    3.75           20111.0           20162.0
# 3          90.0       100.0    4.00           20051.0           20111.0
# 4          95.0        97.0    3.75           20162.0           99999.0
#
#   finish_status grade_show active
# 0             P         A+      A
# 1             P         A+      A
# 2             P          A      A
# 3             P          A      A
# 4             P          A      A
