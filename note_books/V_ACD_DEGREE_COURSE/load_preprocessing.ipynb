# %%
import pandas as pd 
df=pd.read_parquet(r"D:\AI\Real projects\Academic_Advisor\data\raw\v_acd_degree_course.parquet")

# %%
df.head(20)
# df.info()
# Out:
#     degree_course_id  course_id                   course_name_sl  degree_id  \
# 0              1.000        NaN                              NaN        NaN
# 1              1.111    917.111                 الكيمياء الحيوية     17.111
# 2              2.111    923.111       الكيمياء الحيوية التطبيقية     17.111
# 3              3.111    908.111                   الإحصاء الحيوي     17.111
# 4              4.111    891.111              البيولوجيا النباتية     17.111
# 5              5.111    907.111                    تجارة الأدوية     17.111
# 6              6.111    888.111                  الكيمياء العامة     17.111
# 7              7.111    895.111       الكيمياء العامة والتحليلية     17.111
# 8              8.111    897.111        الكيمياء العضوية الأساسية     17.111
# 9              9.111    902.111  الكيمياء العضوية الصيدلانية (1)     17.111
# 10            10.111    909.111  الكيمياء العضوية الصيدلانية (2)     17.111
# ...

# %%
df.head(20)
needed_column=["degree_course_id", "course_id", "degree_id", "course_name_sl", "degree_name_sl", "course_credits", "requirement_type_id", "requirement_type_sl"]
df1=df[needed_column]

# %%
df1
# Out:
#       degree_course_id  course_id  degree_id              course_name_sl  \
# 0                1.000        NaN        NaN                         NaN
# 1                1.111    917.111     17.111            الكيمياء الحيوية
# 2                2.111    923.111     17.111  الكيمياء الحيوية التطبيقية
# 3                3.111    908.111     17.111              الإحصاء الحيوي
# 4                4.111    891.111     17.111         البيولوجيا النباتية
# ...                ...        ...        ...                         ...
# 1695          1613.101   1095.000      3.111                         NaN
# 1696          1614.101   1096.000      3.111                         NaN
# 1697          1615.101   1097.000      3.111                         NaN
# 1698          1616.101   1163.101      3.111                         NaN
# 1699          1617.101   1164.101      3.111                         NaN
#
#                       degree_name_sl  course_credits  requirement_type_id  \
# ...

# %%
df1.isna().sum()
d=df1.drop(index=0,axis=0)

# %%
d.isna().sum()
# Out:
# degree_course_id        0
# course_id               0
# degree_id               0
# course_name_sl         14
# degree_name_sl          0
# course_credits         14
# requirement_type_id     0
# requirement_type_sl     0
# dtype: int64

# %%
d[d["course_credits"].isna()]
d.dropna(axis=0,inplace=True)

# %%
d.to_csv(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ACD_DEGREE_COURSE\v_acd_degree_course.csv",index=False)

# %%
D=pd.read_csv(r"D:\AI\Real projects\Academic_Advisor\data\preprocessed\V_ACD_DEGREE_COURSE\v_acd_degree_course.csv")

# %%
D.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1685 entries, 0 to 1684
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   degree_course_id     1685 non-null   float64
#  1   course_id            1685 non-null   float64
#  2   degree_id            1685 non-null   float64
#  3   course_name_sl       1685 non-null   str
#  4   degree_name_sl       1685 non-null   str
#  5   course_credits       1685 non-null   float64
#  6   requirement_type_id  1685 non-null   float64
#  7   requirement_type_sl  1685 non-null   str
# dtypes: float64(5), str(3)
# memory usage: 307.3 KB
